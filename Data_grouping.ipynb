# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data wrangling (grouping)

# %%
df = pd.read_csv('CN_DB.csv')
df.columns
# Out:
# Index(['suject_id', 'timestamp', 'season', 'city', 'climate', 'building_type',
#        'heating_type', 'gender', 'age', 'ht', 'wt', 'thermal_sensation',
#        'thermal_comfort', 'thermal_acceptability', 'clo', 'met', 'ta', 'rh',
#        'vel', 'tg', 'top', 'tr', 't_out_min', 't_out_monthly', 'latitude'],
#       dtype='object')

# %% [markdown]
# ## Group by city, using mean values

# %%
df_city = df.groupby('city').agg(
    records=('city', 'size'),
    thermal_sensation=('thermal_sensation', 'mean'),
    ta=('ta', 'mean'),
    top=('top', 'mean'),
    rh=('rh', 'mean'),
    vel=('vel', 'mean'),
    met=('met', 'mean'),
    clo=('clo', 'mean'),
    latitude=('latitude', 'mean')
).reset_index()
df_city.head()
# Out:
#               city  records  thermal_sensation         ta        top  \
# 0           Baotou      303           0.016502  19.766997  19.277228
# 1          Beijing      651          -0.027957  22.948541  22.066052
# 2     FujianFuzhou        7          -0.714286  18.100000  18.100000
# 3    FujianNanping        4           0.000000  17.900000  17.900000
# 4  FujianZhenjiang        2          -0.500000  22.900000  22.900000
#
#           rh       vel       met       clo  latitude
# 0  36.356436  0.050000  1.069967  0.341782     40.65
# 1  28.614439  0.072442  1.056989  0.920568     39.90
# 2  67.428571  0.000000  0.885714  0.351429     26.08
# 3  60.250000  0.000000  0.875000  0.417500     26.64
# 4  74.500000  0.000000  0.900000  0.305000     26.10

# %%
# acesending the df by latitude
df_city = df_city.sort_values('latitude')
df_city
# Out:
#                     city  records  thermal_sensation         ta        top  \
# 6            HainanSanya        5           0.600000  24.880000  24.880000
# 5     GuangdongGuangzhou      997          -0.013039  23.850150  23.876128
# 32         YunnanKunming      415          -1.154217  13.617108  13.617108
# 2           FujianFuzhou        7          -0.714286  18.100000  18.100000
# 4        FujianZhenjiang        2          -0.500000  22.900000  22.900000
# 3          FujianNanping        4           0.000000  17.900000  17.900000
# 18         HunanHengyang        1          -1.000000  16.900000  16.900000
# 17         HunanChangsha     1108          -0.396029  17.222563  17.413267
# 29         SichuanZigong       23          -0.217391  11.026087  11.026087
# 20                 Lhasa      355          -1.095775  10.640845  10.640845
# 16            HubeiWuhan      526          -1.551331  12.633080  12.913118
# 27              Shanghai     2131          -0.051713  20.578461  20.837682
# 19      JiangsuChangzhou      144           0.347222  21.397222  20.514583
# 12          HenanNanyang      251          -0.406375  12.221116  12.221116
# 13     HenanPingdingshan        5          -0.800000  17.560000  17.560000
# 23          ShaanxiXi'an     1686           0.520996  23.028351  23.036833
# 11          HenanLuoyang       45          -0.177778  20.160000  19.040000
# 14        HenanZhengzhou       96           0.656250  23.519792  22.296875
# 10          HenanKaifeng        1           0.000000  13.000000  13.000000
# 9           HenanJiaozuo      888          -0.255631  16.798874  16.798874
# 25        ShandongXintai        3           0.333333  22.833333  22.833333
# 24       ShandongQingdao        1           1.000000  23.000000  23.000000
# 7            HebeiHandan       26          -0.384615  19.576923  19.300000
# 28  ShanxiLvliangfenyang        9          -0.222222  21.133333  21.133333
# 26        ShandongYantai        7           0.857143  25.671429  25.671429
# 22        LiaoningDalian     1703           0.293834  22.487551  22.459190
# 30               Tianjin      730           0.220548  24.564521  24.495068
# 1                Beijing      651          -0.027957  22.948541  22.066052
# 0                 Baotou      303           0.016502  19.766997  19.277228
# 15                Hohhot       12          -0.333333  20.733333  20.733333
# 21         LiaoningBenxi       22          -0.136364  19.736364  19.736364
# 31                Turpan      283          -0.031802  18.206714  19.441343
# 8     HeilongjiangHarbin     3552           0.293300  23.085107  22.707995
#
#            rh       vel       met       clo  latitude
# 6   70.200000  0.000000  0.980000  0.332000     18.25
# 5   52.936810  0.100000  1.000000  0.859910     23.13
# 32  16.946988  0.275325  1.084337  0.647133     24.87
# 2   67.428571  0.000000  0.885714  0.351429     26.08
# 4   74.500000  0.000000  0.900000  0.305000     26.10
# 3   60.250000  0.000000  0.875000  0.417500     26.64
# 18  66.000000  0.000000  0.900000  0.660000     26.89
# 17  48.351083  0.029856  1.020217  0.947500     28.23
# 29  66.521739  0.000000  1.000000  1.586522     29.34
# 20  71.191549  0.020000  1.100000  1.253380     29.65
# 16  47.975285  0.085894  1.070342  1.880342     30.58
# 27  52.263726  0.032952  1.097982  0.881595     31.23
# 19  41.180556  0.012708  1.016667  1.147847     31.78
# 12  66.370518  0.000000  1.000000  1.307530     32.99
# 13  57.800000  0.000000  0.940000  0.792000     33.74
# 23  21.916370  0.038488  1.143832  0.730522     34.26
# 11  30.622222  0.000000  0.997778  1.054444     34.62
# 14  28.895833  0.000000  1.012500  1.193229     34.75
# 10  50.000000  0.000000  0.800000  0.420000     34.79
# 9   49.043919  0.020000  1.100000  1.188874     35.24
# 25  31.000000  0.000000  0.900000  0.686667     35.90
# 24  27.000000  0.000000  1.000000  0.500000     36.07
# 7   35.807692  0.000000  0.980769  1.447692     36.62
# 28  40.555556  0.000000  0.966667  0.411111     37.51
# 26  34.000000  0.000000  1.100000  0.804286     37.53
# 22  36.866119  0.000969  0.994304  0.977962     38.92
# 30  27.410959  0.018890  1.160137  0.813616     39.12
# 1   28.614439  0.072442  1.056989  0.920568     39.90
# 0   36.356436  0.050000  1.069967  0.341782     40.65
# 15  36.833333  0.000000  0.958333  0.506667     40.82
# 21  41.090909  0.000000  0.963636  1.035455     41.29
# 31  33.904594  0.023569  1.191166  1.422756     42.94
# 8   32.613457  0.040315  1.006447  0.923361     45.75

# %% [markdown]
# ## Calculate thermal satisfaction rate

# %%
# tsv between +-1.5 in df, then merge it with df_city
df['satisfied'] = df['thermal_sensation'].apply(lambda x: 1 if x >= -1 and x <= 1 else 0)
df_satisfied = df.groupby('city').agg(
    tsr=('satisfied', 'mean')
).reset_index()
df_city = pd.merge(df_city, df_satisfied, on='city')
df_city.head()
# Out:
#                  city  records  thermal_sensation         ta        top  \
# 0         HainanSanya        5           0.600000  24.880000  24.880000
# 1  GuangdongGuangzhou      997          -0.013039  23.850150  23.876128
# 2       YunnanKunming      415          -1.154217  13.617108  13.617108
# 3        FujianFuzhou        7          -0.714286  18.100000  18.100000
# 4     FujianZhenjiang        2          -0.500000  22.900000  22.900000
#
#           rh       vel       met       clo  latitude       tsr
# 0  70.200000  0.000000  0.980000  0.332000     18.25  0.800000
# 1  52.936810  0.100000  1.000000  0.859910     23.13  0.900702
# 2  16.946988  0.275325  1.084337  0.647133     24.87  0.660241
# 3  67.428571  0.000000  0.885714  0.351429     26.08  0.857143
# 4  74.500000  0.000000  0.900000  0.305000     26.10  0.500000

# %% [markdown]
# ## Calcualte the likelihood of central Heating of cities

# %%
print(df['heating_type'].unique())
# Out:
# ['Radiator heating' 'Convection heating' 'Radiant floor heating'
#  'Naturally Ventilated' 'Ceiling capillary heating'
#  'Air conditioning heating' 'Others' 'self-heating' 'Furnace heating'
#  'Floor radiation + fan coil' 'Small electric heater heating']

# %%
# calcualte the percentage of Radiator heating for each city and assign the value to df_city
df_city['p_dh'] = df_city['city'].apply(lambda x: df[df['city'] == x]['heating_type'].value_counts().get('Radiator heating', 0) / df[df['city'] == x]['heating_type'].count())
# calcualte the percentage of Natural ventilation for each city and assign the value to df_city
df_city['p_nv'] = df_city['city'].apply(lambda x: df[df['city'] == x]['heating_type'].value_counts().get('Naturally Ventilated', 0) / df[df['city'] == x]['heating_type'].count())

# %%
# resort the df_city by latitude
df_city = df_city.sort_values(by='latitude')
# reset the index
df_city = df_city.reset_index(drop=True)

# %% [markdown]
# ## Check the likelihood

# %%
# scatter plot the probability of district heating across latitude
plt.scatter(df_city['latitude'], df_city['p_dh'])
plt.xlabel('latitude')
plt.ylabel('probability of district heating')
# Out:
# Text(0, 0.5, 'probability of district heating')

# %%
# print each city name to check details
for i in range(len(df_city)):
    if i >= 10:
        cityname = df_city['city'][i]
        print(cityname)
        print(df_city['p_dh'][i])
        print(df[df['city'] == cityname]['heating_type'].value_counts())
        print(df[df['city'] == cityname]['building_type'].value_counts())
        print("***************************************\n")
        print()
# Out:
# HubeiWuhan
# 0.0
# Naturally Ventilated    526
# Name: heating_type, dtype: int64
# Dormitory       348
# Residential      95
# Educationnal     83
# Name: building_type, dtype: int64
# ***************************************
#
#
# Shanghai
# 0.0
# Convection heating               784
# Radiant floor heating            726
# Naturally Ventilated             390
# Air conditioning heating         200
# Small electric heater heating     23
# Others                             8
# Name: heating_type, dtype: int64
# Office         906
# Residential    858
# Educational    315
# Dormitory       52
# Name: building_type, dtype: int64
# ***************************************
#
#
# JiangsuChangzhou
# 0.0
# Ceiling capillary heating    144
# Name: heating_type, dtype: int64
# Residential    144
# Name: building_type, dtype: int64
# ***************************************
#
#
# HenanNanyang
# 0.0
# Naturally Ventilated        155
# Air conditioning heating     96
# Name: heating_type, dtype: int64
# Residential    251
# Name: building_type, dtype: int64
# ***************************************
#
#
# HenanPingdingshan
# 0.2
# Naturally Ventilated    4
# Radiator heating        1
# Name: heating_type, dtype: int64
# Residential    5
# Name: building_type, dtype: int64
# ***************************************
#
#
# ShaanxiXi'an
# 0.3469750889679715
# Radiant floor heating    594
# Radiator heating         585
# Convection heating       507
# Name: heating_type, dtype: int64
# Office    1686
# Name: building_type, dtype: int64
# ***************************************
#
#
# HenanLuoyang
# 0.0
# Convection heating      43
# Naturally Ventilated     2
# Name: heating_type, dtype: int64
# Office         38
# Residential     7
# Name: building_type, dtype: int64
# ***************************************
#
#
# HenanZhengzhou
# 0.0
# Convection heating       92
# Radiant floor heating     4
# Name: heating_type, dtype: int64
# Office         92
# Residential     4
# Name: building_type, dtype: int64
# ***************************************
#
#
# HenanKaifeng
# 0.0
# Naturally Ventilated    1
# Name: heating_type, dtype: int64
# Residential    1
# Name: building_type, dtype: int64
# ***************************************
#
#
# HenanJiaozuo
# 0.9988738738738738
# Radiator heating        887
# Naturally Ventilated      1
# Name: heating_type, dtype: int64
# Residential    888
# Name: building_type, dtype: int64
# ***************************************
#
#
# ShandongXintai
# 1.0
# Radiator heating    3
# Name: heating_type, dtype: int64
# Residential    3
# Name: building_type, dtype: int64
# ***************************************
#
#
# ShandongQingdao
# 1.0
# Radiator heating    1
# Name: heating_type, dtype: int64
# Residential    1
# Name: building_type, dtype: int64
# ***************************************
#
#
# HebeiHandan
# 1.0
# Radiator heating    26
# Name: heating_type, dtype: int64
# Residential    26
# Name: building_type, dtype: int64
# ***************************************
#
#
# ShanxiLvliangfenyang
# 1.0
# Radiator heating    9
# Name: heating_type, dtype: int64
# Residential    9
# Name: building_type, dtype: int64
# ***************************************
#
#
# ShandongYantai
# 0.8571428571428571
# Radiator heating        6
# Naturally Ventilated    1
# Name: heating_type, dtype: int64
# Residential    6
# Office         1
# Name: building_type, dtype: int64
# ***************************************
#
#
# LiaoningDalian
# 0.7586611861421022
# Radiator heating         1292
# Convection heating        278
# Radiant floor heating      67
# Furnace heating            58
# Naturally Ventilated        8
# Name: heating_type, dtype: int64
# Office             1065
# Dormitory           468
# Residential         112
# Rural residence      58
# Name: building_type, dtype: int64
# ***************************************
#
#
# Tianjin
# 0.04246575342465753
# Floor radiation + fan coil    684
# Radiator heating               31
# Convection heating             15
# Name: heating_type, dtype: int64
# Office    730
# Name: building_type, dtype: int64
# ***************************************
#
#
# Beijing
# 0.7588325652841782
# Radiator heating      494
# Convection heating    157
# Name: heating_type, dtype: int64
# Educational    590
# Office          61
# Name: building_type, dtype: int64
# ***************************************
#
#
# Baotou
# 0.0
# Naturally Ventilated    303
# Name: heating_type, dtype: int64
# Residential    303
# Name: building_type, dtype: int64
# ***************************************
#
#
# Hohhot
# 1.0
# Radiator heating    12
# Name: heating_type, dtype: int64
# Residential    12
# Name: building_type, dtype: int64
# ***************************************
#
#
# LiaoningBenxi
# 0.045454545454545456
# Radiant floor heating    21
# Radiator heating          1
# Name: heating_type, dtype: int64
# Residential    22
# Name: building_type, dtype: int64
# ***************************************
#
#
# Turpan
# 0.0
# Furnace heating         212
# Naturally Ventilated     53
# self-heating             18
# Name: heating_type, dtype: int64
# Residential    283
# Name: building_type, dtype: int64
# ***************************************
#
#
# HeilongjiangHarbin
# 0.9324324324324325
# Radiator heating         3312
# Radiant floor heating     240
# Name: heating_type, dtype: int64
# Educational    1073
# Residential    1037
# Office          973
# Dormitory       469
# Name: building_type, dtype: int64
# ***************************************

# %% [markdown]
# In general, the "Radiator heating" should indicate central heating systems.</br>
# However, for Northern cities, the "Raidiant floor heating", "Floor radiation + fan coil" should also indicate central heating systems.

# %%
# Include Radiant floor heating as central heating
df_city.loc[df_city['city'] == "ShaanxiXi'an", 'p_dh'] = (594+585) / 1686
# Include Radiant floor heating as central heating
df_city.loc[df_city['city'] == "HenanZhengzhou", 'p_dh'] = 4 / 96
# Include Radiant floor heating as central heating
df_city.loc[df_city['city'] == 'LiaoningDalian', 'p_dh'] = (1292+67) / (1292+278+67+58+8)
# Include (floor heating + fan coil) as central heating
df_city.loc[df_city['city'] == 'Tianjin', 'p_dh'] = (684+31)/(684+31+15)
# Wrong data, http://dx.doi.org/10.1016/j.enbuild.2015.12.053
df_city.loc[df_city['city'] == 'Baotou', 'p_dh'] = 1
# Include Radiant floor heating as central heating
df_city.loc[df_city['city'] == 'LiaoningBenxi', 'p_dh'] = 1
# Include Radiant floor heating as central heating
df_city.loc[df_city['city'] == 'HeilongjiangHarbin', 'p_dh'] = 1

# %%
# scatter plot the probability of district heating across latitude
plt.scatter(df_city['latitude'], df_city['p_dh'])
plt.xlabel('latitude')
plt.ylabel('probability of district heating')
# Out:
# Text(0, 0.5, 'probability of district heating')

# %%
df_city[["city", 'records', 'latitude', 'p_dh', 'p_nv']]
# Out:
#                     city  records  latitude      p_dh      p_nv
# 0            HainanSanya        5     18.25  0.000000  1.000000
# 1     GuangdongGuangzhou      997     23.13  0.000000  0.000000
# 2          YunnanKunming      415     24.87  0.000000  0.997590
# 3           FujianFuzhou        7     26.08  0.000000  1.000000
# 4        FujianZhenjiang        2     26.10  0.000000  1.000000
# 5          FujianNanping        4     26.64  0.000000  1.000000
# 6          HunanHengyang        1     26.89  0.000000  1.000000
# 7          HunanChangsha     1108     28.23  0.000000  0.575812
# 8          SichuanZigong       23     29.34  0.000000  1.000000
# 9                  Lhasa      355     29.65  0.005634  0.684507
# 10            HubeiWuhan      526     30.58  0.000000  1.000000
# 11              Shanghai     2131     31.23  0.000000  0.183013
# 12      JiangsuChangzhou      144     31.78  0.000000  0.000000
# 13          HenanNanyang      251     32.99  0.000000  0.617530
# 14     HenanPingdingshan        5     33.74  0.200000  0.800000
# 15          ShaanxiXi'an     1686     34.26  0.699288  0.000000
# 16          HenanLuoyang       45     34.62  0.000000  0.044444
# 17        HenanZhengzhou       96     34.75  0.041667  0.000000
# 18          HenanKaifeng        1     34.79  0.000000  1.000000
# 19          HenanJiaozuo      888     35.24  0.998874  0.001126
# 20        ShandongXintai        3     35.90  1.000000  0.000000
# 21       ShandongQingdao        1     36.07  1.000000  0.000000
# 22           HebeiHandan       26     36.62  1.000000  0.000000
# 23  ShanxiLvliangfenyang        9     37.51  1.000000  0.000000
# 24        ShandongYantai        7     37.53  0.857143  0.142857
# 25        LiaoningDalian     1703     38.92  0.798004  0.004698
# 26               Tianjin      730     39.12  0.979452  0.000000
# 27               Beijing      651     39.90  0.758833  0.000000
# 28                Baotou      303     40.65  1.000000  0.000000
# 29                Hohhot       12     40.82  1.000000  0.000000
# 30         LiaoningBenxi       22     41.29  1.000000  0.000000
# 31                Turpan      283     42.94  0.000000  0.187279
# 32    HeilongjiangHarbin     3552     45.75  1.000000  0.000000

# %%
df_city.loc[df_city['city'] == 'Baotou', 'p_nv'] = 0

# %%
# scatter plot the probability of district heating across latitude
plt.scatter(df_city['latitude'], df_city['p_nv'])
plt.xlabel('latitude')
plt.ylabel('probability of naturally ventilated')
# Out:
# Text(0, 0.5, 'probability of naturally ventilated')

# %% [markdown]
# ## Export CSV

# %%
# for all values in df_city, only keep two decimal places
df_city = df_city.round(2)
# save the df_city to a csv file
df_city.to_csv('CN_DB_CITY.csv', index=False)
